# %%
print("Meu primeiro programa em python! - Victor Graciano")
print("Morra panizo")
# Out:
# Meu primeiro programa em python! - Victor Graciano
# Morra panizo

# %%
# tipos de dados

a = 7
a1 = "aaa"
a2 = 5
print(type(a))
print(type(a1))
print(type(a2))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'int'>

# %%
soma = a + a2
print(soma)
# Out:
# 12

# %%
nome = "Victor Graciano"
print("Meu nome é "+nome)
print("Meu numero é " +str(a))
# Out:
# Meu nome é Victor Graciano
# Meu numero é 7

# %%
RG = 12221
altura = 1.812456
print("nome: %s - RG: %d - altura: %.2f"%(nome,RG,altura))
# Out:
# nome: Victor Graciano - RG: 12221 - altura: 1.81

# %%
nome = input("qual seu nome?")
idade = int(input("qual sua idade?"))
duracao=int(input("qual a duraçao do seu curso?"))
finalcurso = idade + duracao
print(nome + ", voce vai terminar seu curso com %s anos"%(finalcurso))

# %%
nome1 = nome.upper()
print(nome1)

# %%
print(nome.lower())

# %%
novonome = 'fabio'
nome3 = novonome.capitalize()
print(nome3)
