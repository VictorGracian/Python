# %%
var1 = 4
var2 = 6
print(var1!=var2)
# Out:
# True

# %% [markdown]
# mediaP = 5
# mediaAP = 6
# resultado =
#
# print(resultado)

# %%
mediaP = 5
mediaAP = 6
resultado = mediaP >= mediaAP

print(resultado)
# Out:
# False

# %%
result = 4+3*2
print(result)
# Out:
# 10

# %%
result = 2**4
print(result)
# Out:
# 16

# %%
aprovado1 = True
aprovado2 = False

print(aprovado1 and aprovado2)
# Out:
# False

# %%
print(aprovado1 or aprovado2)
# Out:
# True

# %%
print (not aprovado2)
# Out:
# True
